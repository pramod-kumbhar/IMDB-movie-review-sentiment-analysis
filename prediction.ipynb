# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\pramod\OneDrive\Desktop\GEN AI\DL project using RNN\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# load the IMDB dataset word index
word_index=imdb.get_word_index()
reverse_word_index={value: key for key,value in word_index.items()}

# %%
import os

print(os.path.exists("simple_rnn_imdb.h5"))
# Out:
# True

# %%
## load the pre_trained model with ReLU activation
model=load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\pramod\OneDrive\Desktop\GEN AI\DL project using RNN\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[ 0.01926484,  0.00913236, -0.0094408 , ...,  0.01149571,
#           0.04410734, -0.02998549],
#         [-0.00978113,  0.00839704,  0.02652739, ..., -0.00502567,
#           0.0253428 , -0.00630611],
#         [-0.00958585, -0.00872376, -0.00600276, ...,  0.00339675,
#           0.0572397 , -0.03009482],
#         ...,
#         [ 0.03217269,  0.03711186, -0.00059106, ...,  0.00173057,
#          -0.03382163,  0.00629845],
#         [-0.08285431, -0.04917759,  0.07688133, ..., -0.09159969,
#          -0.0451565 , -0.00138237],
#         [ 0.0475802 , -0.07925534, -0.12384591, ...,  0.07533331,
#           0.10778984, -0.08299652]], dtype=float32),
#  array([[ 0.09140597, -0.13726428,  0.13589498, ...,  0.01332434,
#           0.01698381, -0.08521368],
#         [-0.09235219, -0.04313896, -0.12516606, ..., -0.01823245,
#          -0.02351217, -0.01178491],
#         [ 0.02006788, -0.07247578, -0.05214869, ...,  0.10644248,
#          -0.08285408, -0.00286877],
#         ...,
#         [ 0.0477243 , -0.14180021,  0.06644102, ..., -0.00580737,
#           0.11047658,  0.03065703],
#         [-0.11135841, -0.02526558, -0.11973069, ..., -0.1481081 ,
#          -0.00983938, -0.1034961 ],
#         [ 0.10563184, -0.14978479,  0.03466412, ...,  0.0792753 ,
#          -0.08472091, -0.11744388]], dtype=float32),
#  array([[-0.04490906,  0.02150677, -0.00452746, ..., -0.02771911,
#          -0.07251181,  0.0963137 ],
#         [ 0.06044108,  0.24497448,  0.19820412, ..., -0.1620933 ,
#          -0.11537551, -0.08644074],
#         [ 0.00584809, -0.09521279, -0.01934318, ...,  0.04031616,
#           0.01990619,  0.04597017],
#         ...,
#         [-0.00940954, -0.12416804,  0.15308015, ..., -0.09146047,
#          -0.09709916,  0.14637563],
#         [ 0.03817376, -0.08359645,  0.04243416, ...,  0.00458723,
#          -0.01489535, -0.01904537],
#         [-0.03597675,  0.19295837, -0.15972792, ..., -0.15162131,
#          -0.04206803, -0.05646006]], dtype=float32),
#  array([ 0.0051703 ,  0.00629346,  0.0040401 , -0.00549606, -0.00581097,
#          0.01287078,  0.01155753, -0.00255228, -0.00496649,  0.00404127,
#         -0.00526751, -0.00558205, -0.00623579,  0.00371257, -0.00999038,
#         -0.01737699, -0.00696585,  0.0017118 , -0.02758859, -0.01110035,
#         -0.0114199 , -0.00259723, -0.00200838, -0.00884865, -0.00714873,
#         -0.01671107,  0.01879736,  0.01110657, -0.01293977, -0.01734515,
#          0.02865562,  0.00233554,  0.01911012,  0.00190067,  0.00874248,
#         -0.00696757,  0.00130978, -0.02055926, -0.00468657,  0.02357451,
#         -0.00668886, -0.01647641,  0.00571638,  0.01638089, -0.02000824,
#          0.00969271, -0.00986159, -0.00702232, -0.01308774,  0.00546162,
#          0.02847727, -0.01121044, -0.000425  , -0.0153735 ,  0.00322129,
#         -0.00281331, -0.00464441,  0.01416439,  0.00875844, -0.01376566,
#          0.00280299,  0.01650258, -0.03508085,  0.00015931, -0.00697004,
#         -0.00585847,  0.01955751, -0.02048557, -0.00647545,  0.01884228,
#         -0.00893871, -0.01281097, -0.00286532,  0.02021839,  0.01707383,
#         -0.00627816, -0.02592394,  0.01618988,  0.00714258,  0.00542078,
#         -0.02522353, -0.0179005 ,  0.02092988, -0.03357408, -0.04573059,
#         -0.00538219,  0.00541142, -0.00255267, -0.00592947, -0.00176393,
#          0.00691325,  0.01549818, -0.02011981, -0.02627481, -0.01551771,
#         -0.00519118,  0.01146417, -0.00891015,  0.00913898,  0.0080141 ,
#         -0.00225689, -0.00474511,  0.00761249,  0.01267532, -0.00455257,
#          0.020435  ,  0.00040972, -0.01004972,  0.01996488, -0.00971125,
#         -0.02380533, -0.02065746, -0.01191135,  0.08539502,  0.00927908,
#         -0.00213495, -0.01180075,  0.00272189,  0.00014222, -0.00397278,
#          0.02550656, -0.00491636, -0.02824854, -0.00431395, -0.01153503,
#         -0.01585717,  0.01751079,  0.00143101], dtype=float32),
#  array([[-0.56261   ],
#         [-0.12986307],
#         [-0.22161576],
#         [ 0.16161846],
#         [-0.12171308],
#         [-0.04468779],
#         [-0.33660102],
#         [-0.11712303],
#         [-0.7067613 ],
#         [ 0.09593549],
#         [ 0.05549661],
#         [-0.06836996],
#         [-0.11642152],
#         [-0.06361341],
#         [ 0.18669638],
#         [ 0.2223859 ],
#         [-0.10618436],
#         [ 0.7028779 ],
#         [ 0.07301757],
#         [ 0.12024686],
#         [ 0.1794596 ],
#         [-0.127307  ],
#         [-0.04002088],
#         [-0.19558232],
#         [-0.04194793],
#         [ 0.0230733 ],
#         [ 0.27080184],
#         [ 0.20055483],
#         [ 0.00553639],
#         [-0.10689063],
#         [ 0.4328816 ],
#         [ 0.072202  ],
#         [ 0.40429735],
#         [-0.19473176],
#         [ 0.03101876],
#         [-0.1672097 ],
#         [ 0.6305644 ],
#         [ 0.19605048],
#         [ 0.10422758],
#         [ 0.23677985],
#         [-0.11761622],
#         [-0.02572629],
#         [ 0.37905982],
#         [-0.18294673],
#         [-0.30431062],
#         [ 0.21446773],
#         [-0.12993082],
#         [ 0.36945286],
#         [-0.01109304],
#         [-0.10727381],
#         [ 0.14775917],
#         [-0.16239898],
#         [-0.36799452],
#         [ 0.01657472],
#         [ 0.11552178],
#         [-0.15829492],
#         [ 0.20149316],
#         [ 0.4270296 ],
#         [ 0.20396772],
#         [-0.14905164],
#         [ 0.26112825],
#         [-0.12457433],
#         [ 0.07018622],
#         [-0.03268027],
#         [ 0.09647579],
#         [-0.58408874],
#         [ 0.27335113],
#         [ 0.15724818],
#         [-0.3060438 ],
#         [ 0.12169247],
#         [-0.15302256],
#         [-0.16565311],
#         [ 0.04842157],
#         [-0.0585938 ],
#         [ 0.05005118],
#         [ 0.05136098],
#         [ 0.05418816],
#         [ 0.09765606],
#         [-0.07580611],
#         [ 0.01858456],
#         [-0.10609121],
#         [ 0.09902717],
#         [ 0.26863268],
#         [-0.21354859],
#         [ 0.09960657],
#         [ 0.19490391],
#         [-0.10436583],
#         [ 0.18385221],
#         [-0.07931056],
#         [-0.2222027 ],
#         [-0.28577366],
#         [-0.15613787],
#         [-0.18905877],
#         [-0.07826661],
#         [-0.5148658 ],
#         [ 0.12952143],
#         [-0.42484725],
#         [-0.09059491],
#         [-0.52973735],
#         [ 0.21355042],
#         [ 0.0181331 ],
#         [-0.10487278],
#         [-0.5579081 ],
#         [ 0.43018734],
#         [-0.01761745],
#         [ 0.20773523],
#         [-0.07266577],
#         [-0.1893702 ],
#         [ 0.29811478],
#         [-0.0922583 ],
#         [ 0.16398641],
#         [ 0.24309452],
#         [-0.01648588],
#         [-0.23646043],
#         [ 0.22360083],
#         [ 0.1889487 ],
#         [-0.14403804],
#         [ 0.34534553],
#         [-0.19686064],
#         [-0.07537875],
#         [ 0.05394797],
#         [-0.15734631],
#         [ 0.10533725],
#         [-0.12752494],
#         [-0.21964034],
#         [-0.3224626 ],
#         [-0.06287216],
#         [-0.21697778]], dtype=float32),
#  array([-0.21482262], dtype=float32)]

# %%
# fucntion to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i-3,'?')for word in words])

# function to preprocess user input
def preprocess_text(text):
    words=text.lower().split()
    encoded_review=[word_index.get(word,2)+3 for word in words]
    padded_review=sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
# prediction function
def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)
    
    prediction=model.predict(preprocessed_input)
    
    sentiment='Positive' if prediction[0][0]>0.5 else "Negative"
    
    return sentiment, prediction[0][0]

# %%
## step 4: user input and prediction
# example review for prediction
example_review='This movie was fantastic! The acting was great and the plot was thrilling'

sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment:{sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 288ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling
# Sentiment:Positive
# Prediction Score: 0.7656731009483337
